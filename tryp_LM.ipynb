# %% [markdown]
# # Merging the pairs
#
# `bbmerge` package was used in this step

# %%
# %%bash
# input_list_file="sample_list.txt"
# while IFS='' read -r line || [[ -n "$line" ]]; do
#   sample_list="$sample_list $line"
# done <"$input_list_file"
# echo $sample_list
#
# for read in $sample_list; do
#     bbmerge-auto.sh in=$read'_R1.fastq' \
#                in2=$read'_R2.fastq' \
#                out='corrected_'$read'_R1.fastq' \
#                out2='corrected_'$read'_R2.fastq' \
#                ecco=t \
#                mix=t
#
#     bbmerge-auto.sh minoverlap=6 \
#                     mininsert=20 \
#                     mininsert0=20 \
#                     in='corrected_'$read'_R1.fastq' \
#                     in2='corrected_'$read'_R2.fastq' \
#                     out="merged_"$read".fastq" \
#                     outu="unmerged_"$read"_R1.fastq" \
#                     outu2="unmerged_"$read"_R2.fastq"
# done
# Out:
# LM1 LM4 LM5
# java -ea -Xmx24675m -Xms24675m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge in=LM1_R1.fastq in2=LM1_R2.fastq out=corrected_LM1_R1.fastq out2=corrected_LM1_R2.fastq ecco=t mix=t
# Executing jgi.BBMerge [in=LM1_R1.fastq, in2=LM1_R2.fastq, out=corrected_LM1_R1.fastq, out2=corrected_LM1_R2.fastq, ecco=t, mix=t]
# Version 38.86
#
# Writing mergable reads unmerged in two files.
# Started output threads.
# Total time: 93.728 seconds.
#
# Pairs:               	34375177
# Joined:              	16325022   	47.491%
# Ambiguous:           	18050147   	52.509%
# No Solution:         	8       	0.000%
# Too Short:           	0       	0.000%
# Errors Corrected:    	552636
#
# Avg Insert:          	59.3
# Standard Deviation:  	9.5
# Mode:                	70
#
# Insert range:        	35 - 74
# 90th percentile:     	71
# 75th percentile:     	67
# 50th percentile:     	61
# 25th percentile:     	53
# 10th percentile:     	45
# java -ea -Xmx24520m -Xms24520m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge minoverlap=6 mininsert=20 mininsert0=20 in=corrected_LM1_R1.fastq in2=corrected_LM1_R2.fastq out=merged_LM1.fastq outu=unmerged_LM1_R1.fastq outu2=unmerged_LM1_R2.fastq
# Executing jgi.BBMerge [minoverlap=6, mininsert=20, mininsert0=20, in=corrected_LM1_R1.fastq, in2=corrected_LM1_R2.fastq, out=merged_LM1.fastq, outu=unmerged_LM1_R1.fastq, outu2=unmerged_LM1_R2.fastq]
# Version 38.86
#
# Writing mergable reads merged.
# Started output threads.
# Total time: 71.500 seconds.
#
# Pairs:               	34375177
# Joined:              	17284830   	50.283%
# Ambiguous:           	17090339   	49.717%
# No Solution:         	8       	0.000%
# Too Short:           	0       	0.000%
#
# Avg Insert:          	57.7
# Standard Deviation:  	11.4
# Mode:                	70
#
# Insert range:        	20 - 74
# 90th percentile:     	71
# 75th percentile:     	67
# 50th percentile:     	60
# 25th percentile:     	51
# 10th percentile:     	41
# java -ea -Xmx24577m -Xms24577m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge in=LM4_R1.fastq in2=LM4_R2.fastq out=corrected_LM4_R1.fastq out2=corrected_LM4_R2.fastq ecco=t mix=t
# Executing jgi.BBMerge [in=LM4_R1.fastq, in2=LM4_R2.fastq, out=corrected_LM4_R1.fastq, out2=corrected_LM4_R2.fastq, ecco=t, mix=t]
# Version 38.86
#
# Writing mergable reads unmerged in two files.
# Started output threads.
# Total time: 107.425 seconds.
#
# Pairs:               	35117715
# Joined:              	17963712   	51.153%
# Ambiguous:           	17153997   	48.847%
# No Solution:         	6       	0.000%
# Too Short:           	0       	0.000%
# Errors Corrected:    	608187
#
# Avg Insert:          	58.9
# Standard Deviation:  	9.8
# Mode:                	70
#
# Insert range:        	35 - 74
# 90th percentile:     	71
# 75th percentile:     	67
# 50th percentile:     	60
# 25th percentile:     	52
# 10th percentile:     	44
# java -ea -Xmx24569m -Xms24569m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge minoverlap=6 mininsert=20 mininsert0=20 in=corrected_LM4_R1.fastq in2=corrected_LM4_R2.fastq out=merged_LM4.fastq outu=unmerged_LM4_R1.fastq outu2=unmerged_LM4_R2.fastq
# Executing jgi.BBMerge [minoverlap=6, mininsert=20, mininsert0=20, in=corrected_LM4_R1.fastq, in2=corrected_LM4_R2.fastq, out=merged_LM4.fastq, outu=unmerged_LM4_R1.fastq, outu2=unmerged_LM4_R2.fastq]
# Version 38.86
#
# Writing mergable reads merged.
# Started output threads.
# Total time: 57.610 seconds.
#
# Pairs:               	35117715
# Joined:              	19397028   	55.234%
# Ambiguous:           	15720681   	44.766%
# No Solution:         	6       	0.000%
# Too Short:           	0       	0.000%
#
# Avg Insert:          	56.8
# Standard Deviation:  	12.1
# Mode:                	30
#
# Insert range:        	20 - 74
# 90th percentile:     	70
# 75th percentile:     	67
# 50th percentile:     	59
# 25th percentile:     	50
# 10th percentile:     	38
# java -ea -Xmx24598m -Xms24598m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge in=LM5_R1.fastq in2=LM5_R2.fastq out=corrected_LM5_R1.fastq out2=corrected_LM5_R2.fastq ecco=t mix=t
# Executing jgi.BBMerge [in=LM5_R1.fastq, in2=LM5_R2.fastq, out=corrected_LM5_R1.fastq, out2=corrected_LM5_R2.fastq, ecco=t, mix=t]
# Version 38.86
#
# Writing mergable reads unmerged in two files.
# Started output threads.
# Total time: 90.264 seconds.
#
# Pairs:               	29123746
# Joined:              	14443168   	49.592%
# Ambiguous:           	14680570   	50.408%
# No Solution:         	8       	0.000%
# Too Short:           	0       	0.000%
# Errors Corrected:    	526069
#
# Avg Insert:          	59.2
# Standard Deviation:  	9.5
# Mode:                	70
#
# Insert range:        	35 - 74
# 90th percentile:     	71
# 75th percentile:     	67
# 50th percentile:     	60
# 25th percentile:     	52
# 10th percentile:     	46
# java -ea -Xmx24567m -Xms24567m -cp /usr/local/bin/bbmap/current/ jgi.BBMerge minoverlap=6 mininsert=20 mininsert0=20 in=corrected_LM5_R1.fastq in2=corrected_LM5_R2.fastq out=merged_LM5.fastq outu=unmerged_LM5_R1.fastq outu2=unmerged_LM5_R2.fastq
# Executing jgi.BBMerge [minoverlap=6, mininsert=20, mininsert0=20, in=corrected_LM5_R1.fastq, in2=corrected_LM5_R2.fastq, out=merged_LM5.fastq, outu=unmerged_LM5_R1.fastq, outu2=unmerged_LM5_R2.fastq]
# Version 38.86
#
# Writing mergable reads merged.
# Started output threads.
# Total time: 53.480 seconds.
#
# Pairs:               	29123746
# Joined:              	15527011   	53.314%
# Ambiguous:           	13596727   	46.686%
# No Solution:         	8       	0.000%
# Too Short:           	0       	0.000%
#
# Avg Insert:          	57.2
# Standard Deviation:  	11.8
# Mode:                	30
#
# Insert range:        	20 - 74
# 90th percentile:     	71
# 75th percentile:     	67
# 50th percentile:     	59
# 25th percentile:     	51
# 10th percentile:     	39

# %% [markdown]
# # Move UMI to read name and Process with merged reads only
#
# `cutadapt`, as well as `move_umi.py` from https://github.com/yz201906/RibOxi-seq was used in this step

# %%
# %%bash
# input_list_file="sample_list.txt"
# while IFS='' read -r line || [[ -n "$line" ]]; do
#   sample_list="$sample_list $line"
# done <"$input_list_file"
# echo $sample_list
#
# for read in $sample_list; do
#     cat 'merged_'$read'.fastq' "unmerged_"$read"_R1.fastq" > $read'.fastq'
#
#
#     cutadapt -j 12 \
#         --discard-untrimmed \
#         --minimum-length 20 \
#         -a CTGTAGGCACCATCAATGAC \
#         -e 0.1 \
#         -o 'dt_'$read'.fastq' $read'.fastq'
#
#
#     move_umi.py -r 'dt_'$read'.fastq' \
#                 -l 4 \
#                 -o 'umiRemoved_'"$read" \
#                 -i ATCACG \
#                 -a ATCACGCTGTAGGCACCATCAATGAC \
#                 -m 'pipeline'
#
#     cutadapt -j 12 \
#         --discard-untrimmed \
#         --minimum-length 20 \
#         -a ATCACG \
#         -e 0.01 \
#         -o 'trimmed_'$read'.fastq' 'umiRemoved_'$read'_R1.fastq'
#
# done
# Out:
# LM1 LM4 LM5
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a CTGTAGGCACCATCAATGAC -e 0.1 -o dt_LM1.fastq LM1.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 31.64 s (1 us/read; 65.19 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              34,375,177
# Reads with adapters:                17,854,174 (51.9%)
# Reads written (passing filters):    16,214,824 (47.2%)
#
# Total basepairs processed: 1,714,674,384 bp
# Total written (filtered):    648,257,920 bp (37.8%)
#
# === Adapter 1 ===
#
# Sequence: CTGTAGGCACCATCAATGAC; Type: regular 3'; Length: 20; Trimmed: 17854174 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Bases preceding removed adapters:
#   A: 2.3%
#   C: 0.5%
#   G: 96.2%
#   T: 1.0%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by "G" extremely often.
#     The provided adapter sequence could be incomplete at its 3' end.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	280708	537112.1	0	280708
# 4	68914	134278.0	0	68914
# 5	25404	33569.5	0	25404
# 6	21879	8392.4	0	21879
# 7	14225	2098.1	0	14225
# 8	12698	524.5	0	12698
# 9	12453	131.1	0	11799 654
# 10	13134	32.8	1	10138 2996
# 11	18624	8.2	1	14800 3824
# 12	12937	2.0	1	10183 2754
# 13	9898	0.5	1	7494 2404
# 14	8736	0.1	1	6460 2276
# 15	8505	0.0	1	6787 1718
# 16	8517	0.0	1	6595 1922
# 17	7031	0.0	1	5477 1554
# 18	9236	0.0	1	5839 1699 1698
# 19	35814	0.0	1	6098 28153 1563
# 20	17194903	0.0	2	16522946 581570 90387
# 21	12262	0.0	2	4803 6665 794
# 22	4779	0.0	2	3367 866 546
# 23	4641	0.0	2	3282 893 466
# 24	4523	0.0	2	3248 803 472
# 25	5388	0.0	2	3890 1017 481
# 26	7207	0.0	2	5304 1357 546
# 27	5094	0.0	2	3696 965 433
# 28	4795	0.0	2	3600 847 348
# 29	1949	0.0	2	1391 390 168
# 30	308	0.0	2	213 69 26
# 31	331	0.0	2	236 65 30
# 32	31457	0.0	2	23512 5474 2471
# 33	1867	0.0	2	1325 371 171
# 34	312	0.0	2	214 66 32
# 35	179	0.0	2	124 39 16
# 36	111	0.0	2	71 29 11
# 37	55	0.0	2	31 16 8
# 38	62	0.0	2	37 21 4
# 39	44	0.0	2	24 13 7
# 40	68	0.0	2	38 23 7
# 41	27	0.0	2	9 6 12
# 42	5009	0.0	2	22 64 4923
# 43	2	0.0	2	2
# 44	3	0.0	2	3
# 45	1	0.0	2	1
# 46	2	0.0	2	2
# 47	1	0.0	2	0 1
# 48	51	0.0	2	51
# 49	15	0.0	2	15
# 50	13	0.0	2	13
# 51	1	0.0	2	1
# 56	1	0.0	2	1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# Number of merged reads as input:16214824
# Number of non-mispriming reads:16214824
# % passed reads:100.0%
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a ATCACG -e 0.01 -o trimmed_LM1.fastq umiRemoved_LM1_R1.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 15.80 s (1 us/read; 61.58 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              16,214,824
# Reads with adapters:                15,154,274 (93.5%)
# Reads written (passing filters):    13,155,650 (81.1%)
#
# Total basepairs processed:   583,398,624 bp
# Total written (filtered):    425,369,511 bp (72.9%)
#
# === Adapter 1 ===
#
# Sequence: ATCACG; Type: regular 3'; Length: 6; Trimmed: 15154274 times
#
# No. of allowed errors:
# 0-6 bp: 0
#
# Bases preceding removed adapters:
#   A: 36.0%
#   C: 18.0%
#   G: 21.0%
#   T: 25.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	2195	253356.6	0	2195
# 4	1761	63339.2	0	1761
# 5	3370	15834.8	0	3370
# 6	15140251	3958.7	0	15140251
# 7	3576	3958.7	0	3576
# 8	7	3958.7	0	7
# 10	1	3958.7	0	1
# 11	5	3958.7	0	5
# 12	78	3958.7	0	78
# 13	50	3958.7	0	50
# 14	80	3958.7	0	80
# 15	68	3958.7	0	68
# 16	98	3958.7	0	98
# 17	119	3958.7	0	119
# 18	109	3958.7	0	109
# 19	127	3958.7	0	127
# 20	89	3958.7	0	89
# 21	305	3958.7	0	305
# 22	88	3958.7	0	88
# 23	78	3958.7	0	78
# 24	118	3958.7	0	118
# 25	93	3958.7	0	93
# 26	112	3958.7	0	112
# 27	90	3958.7	0	90
# 28	110	3958.7	0	110
# 29	79	3958.7	0	79
# 30	132	3958.7	0	132
# 31	68	3958.7	0	68
# 32	148	3958.7	0	148
# 33	150	3958.7	0	150
# 34	120	3958.7	0	120
# 35	85	3958.7	0	85
# 36	46	3958.7	0	46
# 37	43	3958.7	0	43
# 38	40	3958.7	0	40
# 39	41	3958.7	0	41
# 40	25	3958.7	0	25
# 41	105	3958.7	0	105
# 42	49	3958.7	0	49
# 43	33	3958.7	0	33
# 44	45	3958.7	0	45
# 45	28	3958.7	0	28
# 46	28	3958.7	0	28
# 47	14	3958.7	0	14
# 48	12	3958.7	0	12
# 49	5	3958.7	0	5
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a CTGTAGGCACCATCAATGAC -e 0.1 -o dt_LM4.fastq LM4.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 33.20 s (1 us/read; 63.46 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              35,117,715
# Reads with adapters:                19,973,186 (56.9%)
# Reads written (passing filters):    17,644,632 (50.2%)
#
# Total basepairs processed: 1,762,109,735 bp
# Total written (filtered):    702,234,118 bp (39.9%)
#
# === Adapter 1 ===
#
# Sequence: CTGTAGGCACCATCAATGAC; Type: regular 3'; Length: 20; Trimmed: 19973186 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Bases preceding removed adapters:
#   A: 2.6%
#   C: 0.5%
#   G: 95.7%
#   T: 1.1%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by "G" extremely often.
#     The provided adapter sequence could be incomplete at its 3' end.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	266370	548714.3	0	266370
# 4	59289	137178.6	0	59289
# 5	23129	34294.6	0	23129
# 6	21649	8573.7	0	21649
# 7	14141	2143.4	0	14141
# 8	12222	535.9	0	12222
# 9	12694	134.0	0	12039 655
# 10	13166	33.5	1	10293 2873
# 11	20939	8.4	1	16664 4275
# 12	13209	2.1	1	10336 2873
# 13	10416	0.5	1	7874 2542
# 14	9070	0.1	1	6751 2319
# 15	9037	0.0	1	7119 1918
# 16	9077	0.0	1	7088 1989
# 17	7751	0.0	1	6045 1706
# 18	10637	0.0	1	6531 1907 2199
# 19	43045	0.0	1	7159 34039 1847
# 20	19298514	0.0	2	18578400 627552 92562
# 21	15514	0.0	2	6026 8508 980
# 22	5597	0.0	2	3889 1103 605
# 23	5849	0.0	2	4171 1092 586
# 24	5780	0.0	2	4163 1064 553
# 25	6764	0.0	2	4943 1241 580
# 26	9130	0.0	2	6748 1667 715
# 27	5758	0.0	2	4183 1066 509
# 28	4181	0.0	2	3140 730 311
# 29	1577	0.0	2	1138 319 120
# 30	262	0.0	2	157 63 42
# 31	425	0.0	2	311 85 29
# 32	48081	0.0	2	35945 8587 3549
# 33	2903	0.0	2	2092 559 252
# 34	413	0.0	2	282 100 31
# 35	262	0.0	2	186 51 25
# 36	151	0.0	2	101 29 21
# 37	45	0.0	2	32 11 2
# 38	117	0.0	2	66 40 11
# 39	52	0.0	2	32 10 10
# 40	88	0.0	2	50 31 7
# 41	53	0.0	2	26 15 12
# 42	5710	0.0	2	38 81 5591
# 43	2	0.0	2	1 1
# 44	1	0.0	2	1
# 45	6	0.0	2	5 1
# 46	2	0.0	2	2
# 47	3	0.0	2	3
# 48	72	0.0	2	72
# 49	16	0.0	2	16
# 50	14	0.0	2	14
# 55	2	0.0	2	2
# 60	1	0.0	2	1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# Number of merged reads as input:17644632
# Number of non-mispriming reads:17644632
# % passed reads:100.0%
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a ATCACG -e 0.01 -o trimmed_LM4.fastq umiRemoved_LM4_R1.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 17.14 s (1 us/read; 61.77 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              17,644,632
# Reads with adapters:                16,394,045 (92.9%)
# Reads written (passing filters):    14,094,368 (79.9%)
#
# Total basepairs processed:   631,655,590 bp
# Total written (filtered):    455,727,867 bp (72.1%)
#
# === Adapter 1 ===
#
# Sequence: ATCACG; Type: regular 3'; Length: 6; Trimmed: 16394045 times
#
# No. of allowed errors:
# 0-6 bp: 0
#
# Bases preceding removed adapters:
#   A: 37.5%
#   C: 17.8%
#   G: 20.8%
#   T: 23.9%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	1674	275697.4	0	1674
# 4	1698	68924.3	0	1698
# 5	3776	17231.1	0	3776
# 6	16379686	4307.8	0	16379686
# 7	4232	4307.8	0	4232
# 8	9	4307.8	0	9
# 9	3	4307.8	0	3
# 10	3	4307.8	0	3
# 11	5	4307.8	0	5
# 12	73	4307.8	0	73
# 13	60	4307.8	0	60
# 14	91	4307.8	0	91
# 15	73	4307.8	0	73
# 16	80	4307.8	0	80
# 17	86	4307.8	0	86
# 18	125	4307.8	0	125
# 19	136	4307.8	0	136
# 20	121	4307.8	0	121
# 21	322	4307.8	0	322
# 22	72	4307.8	0	72
# 23	84	4307.8	0	84
# 24	118	4307.8	0	118
# 25	103	4307.8	0	103
# 26	72	4307.8	0	72
# 27	89	4307.8	0	89
# 28	83	4307.8	0	83
# 29	74	4307.8	0	74
# 30	113	4307.8	0	113
# 31	70	4307.8	0	70
# 32	133	4307.8	0	133
# 33	124	4307.8	0	124
# 34	111	4307.8	0	111
# 35	90	4307.8	0	90
# 36	40	4307.8	0	40
# 37	32	4307.8	0	32
# 38	30	4307.8	0	30
# 39	39	4307.8	0	39
# 40	19	4307.8	0	19
# 41	100	4307.8	0	100
# 42	34	4307.8	0	34
# 43	26	4307.8	0	26
# 44	42	4307.8	0	42
# 45	28	4307.8	0	28
# 46	33	4307.8	0	33
# 47	10	4307.8	0	10
# 48	22	4307.8	0	22
# 49	1	4307.8	0	1
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a CTGTAGGCACCATCAATGAC -e 0.1 -o dt_LM5.fastq LM5.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 26.92 s (1 us/read; 64.92 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              29,123,746
# Reads with adapters:                16,102,950 (55.3%)
# Reads written (passing filters):    14,444,394 (49.6%)
#
# Total basepairs processed: 1,459,191,216 bp
# Total written (filtered):    575,647,485 bp (39.4%)
#
# === Adapter 1 ===
#
# Sequence: CTGTAGGCACCATCAATGAC; Type: regular 3'; Length: 20; Trimmed: 16102950 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Bases preceding removed adapters:
#   A: 2.1%
#   C: 0.5%
#   G: 96.3%
#   T: 1.0%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by "G" extremely often.
#     The provided adapter sequence could be incomplete at its 3' end.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	306186	455058.5	0	306186
# 4	52429	113764.6	0	52429
# 5	21062	28441.2	0	21062
# 6	17318	7110.3	0	17318
# 7	12719	1777.6	0	12719
# 8	12968	444.4	0	12968
# 9	12200	111.1	0	11587 613
# 10	13537	27.8	1	10536 3001
# 11	21647	6.9	1	17273 4374
# 12	12734	1.7	1	10038 2696
# 13	9708	0.4	1	7341 2367
# 14	8509	0.1	1	6325 2184
# 15	8330	0.0	1	6593 1737
# 16	7757	0.0	1	5945 1812
# 17	6241	0.0	1	4804 1437
# 18	8429	0.0	1	5522 1722 1185
# 19	30384	0.0	1	5931 23129 1324
# 20	15445708	0.0	2	14854075 506967 84666
# 21	12164	0.0	2	4681 6687 796
# 22	4342	0.0	2	2999 855 488
# 23	4497	0.0	2	3228 830 439
# 24	4377	0.0	2	3126 822 429
# 25	4975	0.0	2	3615 914 446
# 26	6174	0.0	2	4561 1127 486
# 27	3578	0.0	2	2570 696 312
# 28	2116	0.0	2	1578 374 164
# 29	908	0.0	2	668 181 59
# 30	190	0.0	2	128 45 17
# 31	392	0.0	2	284 83 25
# 32	43821	0.0	2	32763 7557 3501
# 33	2657	0.0	2	1904 527 226
# 34	367	0.0	2	254 81 32
# 35	207	0.0	2	148 44 15
# 36	141	0.0	2	92 27 22
# 37	36	0.0	2	26 8 2
# 38	89	0.0	2	54 16 19
# 39	33	0.0	2	20 8 5
# 40	60	0.0	2	38 14 8
# 41	33	0.0	2	11 4 18
# 42	3895	0.0	2	28 40 3827
# 43	1	0.0	2	1
# 45	1	0.0	2	1
# 46	1	0.0	2	0 1
# 48	16	0.0	2	15 1
# 49	7	0.0	2	7
# 50	4	0.0	2	4
# 52	1	0.0	2	1
# 53	1	0.0	2	1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# Number of merged reads as input:14444394
# Number of non-mispriming reads:14444394
# % passed reads:100.0%
# This is cutadapt 2.10 with Python 3.8.5
# Command line parameters: -j 12 --discard-untrimmed --minimum-length 20 -a ATCACG -e 0.01 -o trimmed_LM5.fastq umiRemoved_LM5_R1.fastq
# Processing reads on 12 cores in single-end mode ...
# Finished in 14.49 s (1 us/read; 59.81 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              14,444,394
# Reads with adapters:                13,474,321 (93.3%)
# Reads written (passing filters):    11,709,937 (81.1%)
#
# Total basepairs processed:   517,869,909 bp
# Total written (filtered):    376,772,202 bp (72.8%)
#
# === Adapter 1 ===
#
# Sequence: ATCACG; Type: regular 3'; Length: 6; Trimmed: 13474321 times
#
# No. of allowed errors:
# 0-6 bp: 0
#
# Bases preceding removed adapters:
#   A: 36.6%
#   C: 20.1%
#   G: 20.5%
#   T: 22.8%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	1099	225693.7	0	1099
# 4	1234	56423.4	0	1234
# 5	3057	14105.9	0	3057
# 6	13462089	3526.5	0	13462089
# 7	3415	3526.5	0	3415
# 8	2	3526.5	0	2
# 9	2	3526.5	0	2
# 10	3	3526.5	0	3
# 11	4	3526.5	0	4
# 12	65	3526.5	0	65
# 13	57	3526.5	0	57
# 14	78	3526.5	0	78
# 15	51	3526.5	0	51
# 16	84	3526.5	0	84
# 17	108	3526.5	0	108
# 18	144	3526.5	0	144
# 19	144	3526.5	0	144
# 20	105	3526.5	0	105
# 21	464	3526.5	0	464
# 22	82	3526.5	0	82
# 23	91	3526.5	0	91
# 24	153	3526.5	0	153
# 25	113	3526.5	0	113
# 26	75	3526.5	0	75
# 27	124	3526.5	0	124
# 28	80	3526.5	0	80
# 29	85	3526.5	0	85
# 30	179	3526.5	0	179
# 31	72	3526.5	0	72
# 32	161	3526.5	0	161
# 33	191	3526.5	0	191
# 34	132	3526.5	0	132
# 35	105	3526.5	0	105
# 36	58	3526.5	0	58
# 37	25	3526.5	0	25
# 38	30	3526.5	0	30
# 39	29	3526.5	0	29
# 40	22	3526.5	0	22
# 41	90	3526.5	0	90
# 42	32	3526.5	0	32
# 43	34	3526.5	0	34
# 44	46	3526.5	0	46
# 45	35	3526.5	0	35
# 46	40	3526.5	0	40
# 47	8	3526.5	0	8
# 48	22	3526.5	0	22
# 49	2	3526.5	0	2

# %% [markdown]
# # Process with just Read1 only

# %% [markdown]
# # Alignment
#
# `STAR` was used to perform sequence alignment against curated *Leishmania* rRNA sequences.

# %%
# %%bash
# input_list_file="sample_list.txt"
# while IFS='' read -r line || [[ -n "$line" ]]; do
#   sample_list="$sample_list $line"
# done <"$input_list_file"
# for sample in $sample_list; do
#     mkdir -p $sample
#     STAR --runThreadN 10 \
#       --outMultimapperOrder Random \
#       --outFilterMismatchNoverLmax 0.1 \
#       --alignEndsType EndToEnd \
#       --limitOutSJcollapsed 20000000 \
#       --limitIObufferSize 550000000 \
#       --limitBAMsortRAM 2960722171 \
#       --genomeDir $GENOMES"/LM/" \
#       --readFilesIn 'trimmed_'"$sample"'.fastq' \
#       --outFileNamePrefix ./"$sample"/ \
#       --genomeLoad LoadAndKeep \
#       --outSAMtype BAM SortedByCoordinate
# #       --outFilterScoreMinOverLread 0.8 \
# #       --outFilterMatchNminOverLread 0.8 \
# done
#
# STAR --genomeDir $GENOMES"/LM/" --genomeLoad Remove
# Out:
# May 11 23:04:07 ..... started STAR run
# May 11 23:04:07 ..... loading genome
# May 11 23:04:07 ..... started mapping
# May 11 23:04:34 ..... finished mapping
# May 11 23:04:35 ..... started sorting BAM
# May 11 23:04:52 ..... finished successfully
# May 11 23:04:53 ..... started STAR run
# May 11 23:04:53 ..... loading genome
# May 11 23:04:53 ..... started mapping
# May 11 23:05:16 ..... finished mapping
# May 11 23:05:16 ..... started sorting BAM
# May 11 23:05:33 ..... finished successfully
# May 11 23:05:34 ..... started STAR run
# May 11 23:05:34 ..... loading genome
# May 11 23:05:34 ..... started mapping
# May 11 23:05:51 ..... finished mapping
# May 11 23:05:52 ..... started sorting BAM
# May 11 23:06:02 ..... finished successfully
# May 11 23:06:06 ..... started STAR run
# May 11 23:06:06 ..... loading genome
# May 11 23:06:06 ..... started mapping
# May 11 23:06:06 ..... finished mapping
# May 11 23:06:06 ..... finished successfully

# %% [markdown]
# # Post alignment processing
#
# `samtools` was used to index the alignment output.
# `umi_tools` was used to remove PCR duplicates.
# `bedtools` was used to generate human readable bed files for downstream analysis.

# %%
# %%bash
# # Read in sample from out list and store as a variable:
# input_list_file="sample_list.txt"
# while IFS='' read -r line || [[ -n "$line" ]]; do
#   sample_list="$sample_list $line"
# done <"$input_list_file"
# for sample in $sample_list; do
#   cd "$sample"
#   samtools index "Aligned.sortedByCoord.out.bam"
#   umi_tools dedup -I "Aligned.sortedByCoord.out.bam" -S $sample'_dedup.bam'
#   bedtools bamtobed -i $sample'_dedup.bam' >'../bed_files/SE_aligned/'$sample'.bed'
#   cd ../
# done
# Out:
# # UMI-tools version: 1.0.1
# # output generated by dedup -I Aligned.sortedByCoord.out.bam -S LM1_dedup.bam
# # job started at Tue May 11 23:07:43 2021 on yzylhome -- 8135461f-fd54-494c-8f89-31ea84f213bb
# # pid: 8184, system: Linux 5.4.0-73-generic #82-Ubuntu SMP Wed Apr 14 17:39:42 UTC 2021 x86_64
# # assigned_tag                            : None
# # cell_tag                                : None
# # cell_tag_delim                          : None
# # cell_tag_split                          : -
# # chimeric_pairs                          : use
# # chrom                                   : None
# # compresslevel                           : 6
# # detection_method                        : None
# # gene_tag                                : None
# # gene_transcript_map                     : None
# # get_umi_method                          : read_id
# # ignore_umi                              : False
# # in_sam                                  : False
# # log2stderr                              : False
# # loglevel                                : 1
# # mapping_quality                         : 0
# # method                                  : directional
# # no_sort_output                          : False
# # out_sam                                 : False
# # output_unmapped                         : False
# # paired                                  : False
# # per_cell                                : False
# # per_contig                              : False
# # per_gene                                : False
# # random_seed                             : None
# # read_length                             : False
# # short_help                              : None
# # skip_regex                              : ^(__|Unassigned)
# # soft_clip_threshold                     : 4
# # spliced                                 : False
# # stats                                   : False
# # stderr                                  : <_io.TextIOWrapper name='<stderr>' mode='w' encoding='utf-8'>
# # stdin                                   : <_io.TextIOWrapper name='Aligned.sortedByCoord.out.bam' mode='r' encoding='UTF-8'>
# # stdlog                                  : <_io.TextIOWrapper name='<stdout>' mode='w' encoding='utf-8'>
# # stdout                                  : <_io.TextIOWrapper name='LM1_dedup.bam' mode='w' encoding='UTF-8'>
# # subset                                  : None
# # threshold                               : 1
# # timeit_file                             : None
# # timeit_header                           : None
# # timeit_name                             : all
# # tmpdir                                  : None
# # umi_sep                                 : _
# # umi_tag                                 : RX
# # umi_tag_delim                           : None
# # umi_tag_split                           : None
# # unmapped_reads                          : discard
# # unpaired_reads                          : use
# # whole_contig                            : False
# 2021-05-11 23:07:43,288 INFO command: dedup -I Aligned.sortedByCoord.out.bam -S LM1_dedup.bam
# 2021-05-11 23:08:11,953 INFO Parsed 1000000 input reads
# 2021-05-11 23:08:13,399 INFO Parsed 2000000 input reads
# 2021-05-11 23:08:15,000 INFO Parsed 3000000 input reads
# 2021-05-11 23:08:20,689 INFO Parsed 4000000 input reads
# 2021-05-11 23:08:47,170 INFO Written out 100000 reads
# 2021-05-11 23:08:48,065 INFO Parsed 5000000 input reads
# 2021-05-11 23:08:49,046 INFO Parsed 6000000 input reads
# 2021-05-11 23:08:50,335 INFO Parsed 7000000 input reads
# 2021-05-11 23:09:27,382 INFO Parsed 8000000 input reads
# 2021-05-11 23:09:28,617 INFO Parsed 9000000 input reads
# 2021-05-11 23:09:30,078 INFO Parsed 10000000 input reads
# 2021-05-11 23:09:30,098 INFO Written out 200000 reads
# 2021-05-11 23:09:30,452 INFO Parsed 11000000 input reads
# 2021-05-11 23:09:32,636 INFO Parsed 12000000 input reads
# 2021-05-11 23:09:37,014 INFO Reads: Input Reads: 12428626
# 2021-05-11 23:09:37,014 INFO Number of reads out: 222357
# 2021-05-11 23:09:37,014 INFO Total number of positions deduplicated: 6108
# 2021-05-11 23:09:37,014 INFO Mean number of unique UMIs per position: 161.00
# 2021-05-11 23:09:37,014 INFO Max. number of unique UMIs per position: 280
# # job finished in 113 seconds at Tue May 11 23:09:37 2021 -- 113.84  1.47  0.00  0.00 -- 8135461f-fd54-494c-8f89-31ea84f213bb
# # UMI-tools version: 1.0.1
# # output generated by dedup -I Aligned.sortedByCoord.out.bam -S LM4_dedup.bam
# # job started at Tue May 11 23:09:40 2021 on yzylhome -- f0863c19-f1f1-4b5f-8f84-3fd546f8af6d
# # pid: 8214, system: Linux 5.4.0-73-generic #82-Ubuntu SMP Wed Apr 14 17:39:42 UTC 2021 x86_64
# # assigned_tag                            : None
# # cell_tag                                : None
# # cell_tag_delim                          : None
# # cell_tag_split                          : -
# # chimeric_pairs                          : use
# # chrom                                   : None
# # compresslevel                           : 6
# # detection_method                        : None
# # gene_tag                                : None
# # gene_transcript_map                     : None
# # get_umi_method                          : read_id
# # ignore_umi                              : False
# # in_sam                                  : False
# # log2stderr                              : False
# # loglevel                                : 1
# # mapping_quality                         : 0
# # method                                  : directional
# # no_sort_output                          : False
# # out_sam                                 : False
# # output_unmapped                         : False
# # paired                                  : False
# # per_cell                                : False
# # per_contig                              : False
# # per_gene                                : False
# # random_seed                             : None
# # read_length                             : False
# # short_help                              : None
# # skip_regex                              : ^(__|Unassigned)
# # soft_clip_threshold                     : 4
# # spliced                                 : False
# # stats                                   : False
# # stderr                                  : <_io.TextIOWrapper name='<stderr>' mode='w' encoding='utf-8'>
# # stdin                                   : <_io.TextIOWrapper name='Aligned.sortedByCoord.out.bam' mode='r' encoding='UTF-8'>
# # stdlog                                  : <_io.TextIOWrapper name='<stdout>' mode='w' encoding='utf-8'>
# # stdout                                  : <_io.TextIOWrapper name='LM4_dedup.bam' mode='w' encoding='UTF-8'>
# # subset                                  : None
# # threshold                               : 1
# # timeit_file                             : None
# # timeit_header                           : None
# # timeit_name                             : all
# # tmpdir                                  : None
# # umi_sep                                 : _
# # umi_tag                                 : RX
# # umi_tag_delim                           : None
# # umi_tag_split                           : None
# # unmapped_reads                          : discard
# # unpaired_reads                          : use
# # whole_contig                            : False
# 2021-05-11 23:09:40,655 INFO command: dedup -I Aligned.sortedByCoord.out.bam -S LM4_dedup.bam
# 2021-05-11 23:10:11,418 INFO Parsed 1000000 input reads
# 2021-05-11 23:10:12,859 INFO Parsed 2000000 input reads
# 2021-05-11 23:10:14,409 INFO Parsed 3000000 input reads
# 2021-05-11 23:10:20,772 INFO Parsed 4000000 input reads
# 2021-05-11 23:10:47,843 INFO Written out 100000 reads
# 2021-05-11 23:10:48,370 INFO Parsed 5000000 input reads
# 2021-05-11 23:10:49,331 INFO Parsed 6000000 input reads
# 2021-05-11 23:10:50,563 INFO Parsed 7000000 input reads
# 2021-05-11 23:11:37,729 INFO Parsed 8000000 input reads
# 2021-05-11 23:11:38,950 INFO Parsed 9000000 input reads
# 2021-05-11 23:11:40,156 INFO Parsed 10000000 input reads
# 2021-05-11 23:11:40,943 INFO Parsed 11000000 input reads
# 2021-05-11 23:11:41,021 INFO Parsed 12000000 input reads
# 2021-05-11 23:11:41,244 INFO Written out 200000 reads
# 2021-05-11 23:11:43,338 INFO Parsed 13000000 input reads
# 2021-05-11 23:11:47,785 INFO Reads: Input Reads: 13394914
# 2021-05-11 23:11:47,785 INFO Number of reads out: 213916
# 2021-05-11 23:11:47,785 INFO Total number of positions deduplicated: 6108
# 2021-05-11 23:11:47,785 INFO Mean number of unique UMIs per position: 160.05
# 2021-05-11 23:11:47,785 INFO Max. number of unique UMIs per position: 297
# # job finished in 127 seconds at Tue May 11 23:11:47 2021 -- 127.03  1.45  0.00  0.00 -- f0863c19-f1f1-4b5f-8f84-3fd546f8af6d
# # UMI-tools version: 1.0.1
# # output generated by dedup -I Aligned.sortedByCoord.out.bam -S LM5_dedup.bam
# # job started at Tue May 11 23:11:50 2021 on yzylhome -- cd870821-951e-46a5-b2f0-46ca3742923c
# # pid: 8245, system: Linux 5.4.0-73-generic #82-Ubuntu SMP Wed Apr 14 17:39:42 UTC 2021 x86_64
# # assigned_tag                            : None
# # cell_tag                                : None
# # cell_tag_delim                          : None
# # cell_tag_split                          : -
# # chimeric_pairs                          : use
# # chrom                                   : None
# # compresslevel                           : 6
# # detection_method                        : None
# # gene_tag                                : None
# # gene_transcript_map                     : None
# # get_umi_method                          : read_id
# # ignore_umi                              : False
# # in_sam                                  : False
# # log2stderr                              : False
# # loglevel                                : 1
# # mapping_quality                         : 0
# # method                                  : directional
# # no_sort_output                          : False
# # out_sam                                 : False
# # output_unmapped                         : False
# # paired                                  : False
# # per_cell                                : False
# # per_contig                              : False
# # per_gene                                : False
# # random_seed                             : None
# # read_length                             : False
# # short_help                              : None
# # skip_regex                              : ^(__|Unassigned)
# # soft_clip_threshold                     : 4
# # spliced                                 : False
# # stats                                   : False
# # stderr                                  : <_io.TextIOWrapper name='<stderr>' mode='w' encoding='utf-8'>
# # stdin                                   : <_io.TextIOWrapper name='Aligned.sortedByCoord.out.bam' mode='r' encoding='UTF-8'>
# # stdlog                                  : <_io.TextIOWrapper name='<stdout>' mode='w' encoding='utf-8'>
# # stdout                                  : <_io.TextIOWrapper name='LM5_dedup.bam' mode='w' encoding='UTF-8'>
# # subset                                  : None
# # threshold                               : 1
# # timeit_file                             : None
# # timeit_header                           : None
# # timeit_name                             : all
# # tmpdir                                  : None
# # umi_sep                                 : _
# # umi_tag                                 : RX
# # umi_tag_delim                           : None
# # umi_tag_split                           : None
# # unmapped_reads                          : discard
# # unpaired_reads                          : use
# # whole_contig                            : False
# 2021-05-11 23:11:50,898 INFO command: dedup -I Aligned.sortedByCoord.out.bam -S LM5_dedup.bam
# 2021-05-11 23:12:13,473 INFO Parsed 1000000 input reads
# 2021-05-11 23:12:15,736 INFO Parsed 2000000 input reads
# 2021-05-11 23:12:22,161 INFO Parsed 3000000 input reads
# 2021-05-11 23:12:37,732 INFO Written out 100000 reads
# 2021-05-11 23:12:38,084 INFO Parsed 4000000 input reads
# 2021-05-11 23:12:43,151 INFO Parsed 5000000 input reads
# 2021-05-11 23:13:25,279 INFO Parsed 6000000 input reads
# 2021-05-11 23:13:26,166 INFO Parsed 7000000 input reads
# 2021-05-11 23:13:27,422 INFO Parsed 8000000 input reads
# 2021-05-11 23:13:27,745 INFO Parsed 9000000 input reads
# 2021-05-11 23:13:28,023 INFO Parsed 10000000 input reads
# 2021-05-11 23:13:35,260 INFO Written out 200000 reads
# 2021-05-11 23:13:36,443 INFO Reads: Input Reads: 10821953
# 2021-05-11 23:13:36,443 INFO Number of reads out: 201168
# 2021-05-11 23:13:36,443 INFO Total number of positions deduplicated: 6097
# 2021-05-11 23:13:36,443 INFO Mean number of unique UMIs per position: 151.75
# 2021-05-11 23:13:36,443 INFO Max. number of unique UMIs per position: 288
# # job finished in 105 seconds at Tue May 11 23:13:36 2021 -- 105.49  1.38  0.00  0.00 -- cd870821-951e-46a5-b2f0-46ca3742923c
